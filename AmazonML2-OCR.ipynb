# %%
# GPU
# !python3 -m pip install paddlepaddle-gpu==2.6.1.post120 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html

# CPU
# !pip install paddlepaddle
# Out:
# Looking in links: https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.8/796.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.5 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/PaddlePaddle/PaddleOCR
# Out:
# Cloning into 'PaddleOCR'...
# remote: Enumerating objects: 51247, done.
# remote: Counting objects: 100% (2471/2471), done.
# remote: Compressing objects: 100% (1194/1194), done.
# remote: Total 51247 (delta 1289), reused 2243 (delta 1230), pack-reused 48776 (from 1)
# Receiving objects: 100% (51247/51247), 385.61 MiB | 29.45 MiB/s, done.
# Resolving deltas: 100% (35678/35678), done.
# Updating files: 100% (2390/2390), done.

# %%
# !pip3 install -r /content/PaddleOCR/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 37.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 31.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.15
#     Uninstalling albumentations-1.4.15:
#       Successfully uninstalled albumentations-1.4.15
# ...

# %%
# !pip install paddleocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.5/407.5 kB 18.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 20.5 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=058b759e25a213071c1df9e615503ee60f85adbe5a73d75880551dd4a6a23ed3
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...

# %%
import paddleocr
# ocr = paddleocr.PaddleOCR(lang="en")
ocr = paddleocr.PaddleOCR(use_angle_cls=True, lang="en")
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 4.00M/4.00M [00:19<00:00, 201kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10.2M/10.2M [00:21<00:00, 486kiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2.19M/2.19M [00:01<00:00, 1.70MiB/s]
# ...

# %%
import re
import os
import requests
import pandas as pd
import multiprocessing
import time
from time import time as timer
from tqdm import tqdm
import numpy as np
from pathlib import Path
from functools import partial
import requests
import urllib
from PIL import Image
from io import BytesIO


def create_placeholder_image(image_save_path):
    try:
        placeholder_image = Image.new('RGB', (100, 100), color='black')
        placeholder_image.save(image_save_path)
    except Exception as e:
        return

def download_image(image_link, save_folder, retries=3, delay=3):
    if not isinstance(image_link, str):
        return

    filename = Path(image_link).name
    image_save_path = os.path.join(save_folder, filename)

    if os.path.exists(image_save_path):
        return

    for _ in range(retries):
        try:
            urllib.request.urlretrieve(image_link, image_save_path)
            return
        except:
            time.sleep(delay)

    create_placeholder_image(image_save_path) #Create a black placeholder image for invalid links/images

def download_images(image_links, download_folder, allow_multiprocessing=True):
    if not os.path.exists(download_folder):
        os.makedirs(download_folder)

    if allow_multiprocessing:
        download_image_partial = partial(download_image, save_folder=download_folder, retries=3, delay=3)

        with multiprocessing.Pool(64) as pool:
            list(tqdm(pool.imap(download_image_partial, image_links), total=len(image_links)))
            pool.close()
            pool.join()
    else:
        for image_link in tqdm(image_links, total=len(image_links)):
            download_image(image_link, save_folder=download_folder, retries=3, delay=3)


def getImageByLink(image_link):
    response = requests.get(image_link)
    img = Image.open(BytesIO(response.content))

    # Convert the image to a format that PaddleOCR can process
    img = img.convert('RGB')
    img = np.array(img)

    return img

# %%
import os
import pandas as pd

def get_text_from_image(image_link):
    try:
        img = getImageByLink(image_link)
        result = ocr.ocr(img)

        if result is not None and len(result) > 0 and result[0] is not None:
            texts = [res[1][0] for res in result[0]]
            extracted_text = "--".join(texts)
        else:
            extracted_text = "No text extracted"
    except Exception as e:
        extracted_text = f"Error during extraction: {str(e)}"

    return extracted_text

def get_text_from_img(df, save_interval=500, save_path='/content/train_text.csv'):
    df['extracted_text'] = ""

    for i in range(len(df)):
        try:
            img = getImageByLink(df['image_link'][i])
            result = ocr.ocr(img)

            if result is not None and len(result) > 0 and result[0] is not None:
                texts = [res[1][0] for res in result[0]]
                extractedContext = "--".join(texts)
            else:
                extractedContext = "No text extracted"

            df['extracted_text'][i] = extractedContext
        except Exception as e:
            df['extracted_text'][i] = f"Error during extraction: {str(e)}"

        # Save the DataFrame every `save_interval` iterations
        if (i + 1) % save_interval == 0:
            df.to_csv(save_path, index=False)
            print(f"Saved progress at {i + 1} images")

    # Final save to ensure the last batch is saved
    df.to_csv(save_path, index=False)
    print("Final save completed")

    return df

# Example usage
df = pd.read_csv('/content/train.csv', encoding='latin-1')
df1 = df[:30000].copy()
df1.reset_index(drop=True, inplace=True)

df2 = get_text_from_img(df1, save_interval=50, save_path='./drive/MyDrive/Colab Notebooks/Datasets/AmazonML/train_text.csv')
# Out:
# Streaming output truncated to the last 5000 lines.
# [2024/09/17 21:12:44] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.034102678298950195
# [2024/09/17 21:12:44] ppocr DEBUG: cls num  : 4, elapsed : 0.008573055267333984
# [2024/09/17 21:12:44] ppocr DEBUG: rec_res num  : 4, elapsed : 0.01188516616821289
# [2024/09/17 21:12:44] ppocr DEBUG: dt_boxes num : 45, elapsed : 0.04668569564819336
# [2024/09/17 21:12:44] ppocr DEBUG: cls num  : 45, elapsed : 0.05228900909423828
# [2024/09/17 21:12:44] ppocr DEBUG: rec_res num  : 45, elapsed : 0.10566973686218262
# [2024/09/17 21:12:45] ppocr DEBUG: dt_boxes num : 47, elapsed : 0.055428504943847656
# [2024/09/17 21:12:45] ppocr DEBUG: cls num  : 47, elapsed : 0.05837869644165039
# [2024/09/17 21:12:45] ppocr DEBUG: rec_res num  : 47, elapsed : 0.13158917427062988
# [2024/09/17 21:12:45] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.016886472702026367
# [2024/09/17 21:12:45] ppocr DEBUG: cls num  : 4, elapsed : 0.008601188659667969
# ...

# %%
df2.to_csv("./drive/MyDrive/Colab Notebooks/Datasets/AmazonML/train_text.csv", index=False)
df2.to_csv("/content/train_text.csv", index=False)
print(df2.shape)
# Out:
# (30000, 5)

# %%
df1.head()
# Out:
#    index                                         image_link  group_id  \
# 0   2004  https://m.media-amazon.com/images/I/4107YHaKHY...    348551
# 1   2005  https://m.media-amazon.com/images/I/4107YHaKHY...    348551
# 2   2006  https://m.media-amazon.com/images/I/4107hqnUv2...    501250
# 3   2007  https://m.media-amazon.com/images/I/4108Ud0GgI...    658003
# 4   2008  https://m.media-amazon.com/images/I/4108ZITX2n...    276611
#
#   entity_name                                     extracted_text
# 0     wattage  6838--LUTRON--COOPERSBURG,FA--A--120V~--60Hz--...
# 1     voltage  6838--LUTRON--COOPERSBURG,FA--A--120V~--60Hz--...
# 2     voltage  33FT Extension Cord--SJTW3/C 16 AWG--Indoor--o...
# 3      height
# 4      height

# %%
df1.tail()
# Out:
#      index                                         image_link  group_id  \
# 995   3000  https://m.media-amazon.com/images/I/413xn0TpPa...    705487
# 996   3001  https://m.media-amazon.com/images/I/413xwUX8dI...    681445
# 997   3002  https://m.media-amazon.com/images/I/413xwUX8dI...    681445
# 998   3003  https://m.media-amazon.com/images/I/413y0gHI5x...    711228
# 999   3004  https://m.media-amazon.com/images/I/413y0gHI5x...    711228
#
#     entity_name extracted_text
# 995       depth
# 996      height
# 997       depth
# 998       width
# 999       depth
